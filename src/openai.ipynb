# %%
import os
import openai


openai.api_key = "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"

response = openai.Completion.create(model="text-davinci-003", prompt="Say this is a test", temperature=0, max_tokens=7)

# %%
response
# Out:
# <OpenAIObject text_completion id=cmpl-76Iwz3zev0uScbxNcXKVgGYewVwCj at 0x7fe8724f3e00> JSON: {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nThis is indeed a test"
#     }
#   ],
#   "created": 1681737169,
#   "id": "cmpl-76Iwz3zev0uScbxNcXKVgGYewVwCj",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 7,
#     "prompt_tokens": 5,
#     "total_tokens": 12
#   }
# }

# %%
## CLASSIFICATION

response = openai.Completion.create(
  model="text-davinci-003",
  prompt="The following is a list of companies and the categories they fall into:\n\nApple, Facebook, Fedex\n\nApple\nCategory:",
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)
response
# Out:
# <OpenAIObject text_completion id=cmpl-76J2FJHebX64FDtQudrcyPesDouIc at 0x7fe8724f8090> JSON: {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": " Technology\n\nFacebook\nCategory: Social Media\n\nFedex\nCategory: Logistics/Shipping"
#     }
#   ],
#   "created": 1681737495,
#   "id": "cmpl-76J2FJHebX64FDtQudrcyPesDouIc",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 20,
#     "prompt_tokens": 28,
#     "total_tokens": 48
#   }
# }
